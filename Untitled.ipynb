# %%
import pandas as pd
import numpy as np

# %%
witheld = pd.read_csv('witheld_dataset.csv')

# %%
witheld[witheld['rating'] == 5]
# Out:
#     userid     itemid  rating     Time Location Companion
# 0     1082  tt0133093       5  Weekend   Cinema     Alone
# 1     1082  tt0367594       5  Weekend   Cinema     Alone
# 2     1082  tt0405422       5  Weekend     Home    Family
# 3     1082  tt1453405       5  Weekday   Cinema   Partner
# 4     1082  tt0367594       5  Weekday   Cinema   Partner
# 5     1082  tt1453405       5  Weekday   Cinema   Partner
# 6     1082  tt0133093       5  Weekday   Cinema   Partner
# 7     1082  tt1055369       5  Weekend   Cinema     Alone
# 8     1082  tt1632708       5  Weekend   Cinema     Alone
# 9     1082  tt0367594       5  Weekend   Cinema     Alone
# 10    1082  tt0110357       5  Weekday   Cinema   Partner
# 11    1082  tt0111161       5  Weekend     Home    Family
# 12    1082  tt1632708       5  Weekend     Home    Family
# 13    1082  tt0120338       5  Weekday   Cinema   Partner
# 14    1082  tt1055369       5  Weekday   Cinema   Partner
# ...
